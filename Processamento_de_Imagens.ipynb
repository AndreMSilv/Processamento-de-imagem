# %%
#Instando Pillow

# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import PIL

# %%
from PIL import Image

# %% [markdown]
# Carregar imagem pro Disco

# %%
image = Image.open("/content/sample_data/imagem/onpiece.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7FF52B68F9D0>

# %% [markdown]
# formato da imagem

# %%
print(image.format)
# Out:
# JPEG

# %% [markdown]
# imprimindo formade pixels

# %%
print(image.mode)
# Out:
# RGB

# %% [markdown]
# imprimindo dimensoes da imagem

# %%
print(image.size)
# Out:
# (300, 168)

# %% [markdown]
# importanto as bibliotecas para visualização das imagens

# %%
from matplotlib import image
from matplotlib import pyplot

# %% [markdown]
# carregando imagem

# %%
data = image.imread ("/content/sample_data/imagem/onpiece.jpg")

# %% [markdown]
# Imprimindo ....

# %%
print (data)
# Out:
# [[[254 254 246]
#   [254 254 246]
#   [254 254 246]
#   ...
#   [255 253 234]
#   [255 253 234]
#   [255 253 234]]
#
#  [[254 254 244]
#   [254 254 244]
#   [254 254 244]
#   ...
#   [255 253 234]
#   [255 253 234]
#   [255 253 234]]
#
#  [[254 254 244]
#   [254 254 244]
#   [254 254 244]
#   ...
#   [255 253 234]
#   [255 253 234]
#   [255 253 234]]
#
#  ...
#
#  [[ 34   7  16]
#   [ 34   7  16]
#   [ 33   7  16]
#   ...
#   [152 153 158]
#   [152 153 158]
#   [152 153 158]]
#
#  [[ 34   7  16]
#   [ 34   7  16]
#   [ 33   7  16]
#   ...
#   [152 153 158]
#   [152 153 158]
#   [152 153 158]]
#
#  [[ 34   7  16]
#   [ 34   7  16]
#   [ 33   7  16]
#   ...
#   [152 153 158]
#   [152 153 158]
#   [152 153 158]]]

# %% [markdown]
# imprimindo propriedades pixels

# %%
print(data.dtype)
# Out:
# uint8

# %%
print(data.shape)
# Out:
# (168, 300, 3)

# %%
print(data.max())
# Out:
# 255

# %%
print(data.min())
# Out:
# 0

# %% [markdown]
# exibindo o array de pixels como uma imagem

# %%
pyplot.imshow(data)

# %% [markdown]
# convertendo array de pixels em um objeto imagem Pillow

# %%
image2 = Image.fromarray(data)

# %% [markdown]
# Verifcando o tipo de objeto

# %%
type (image2)
# Out:
# PIL.Image.Image

# %% [markdown]
# convertendo um objeto do tipo imagem para array numpy

# %%
from numpy import asarray

# %%
image = Image.open("/content/sample_data/imagem/onpiece.jpg")

# %% [markdown]
# metodo para realizar conversão

# %%
data = asarray(image)

# %% [markdown]
# convertendo a imagem em escala de Cinza

# %%
image_cinza = image.convert (mode="L")

# %%
image_cinza
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7FF529F7C850>

# %% [markdown]
# Salvando Imagem

# %%
image_cinza.save("/content/sample_data/imagem/onpiece-cinza.jpg")

# %%
import cv2
img = cv2.imread("/content/sample_data/imagem/onpiece-cinza.jpg")
thresh, img_thresh = cv2.threshold(img, 230, 255, cv2.THRESH_BINARY)
